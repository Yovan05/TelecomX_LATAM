# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
url = '/content/TelecomX_Data.json'

# %%
clientes = pd.read_json(url)

# %%
clientes
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
clientes_normalizados = pd.json_normalize(clientes.to_dict(orient="records"))
clientes_normalizados
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7262               No                  No               13                Yes
# 7263              Yes                  No               22                Yes
# 7264               No                  No                2                Yes
# 7265              Yes                 Yes               67                Yes
# 7266              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ... internet.OnlineBackup  \
# 0                     No                      DSL  ...                   Yes
# 1                    Yes                      DSL  ...                    No
# 2                     No              Fiber optic  ...                    No
# 3                     No              Fiber optic  ...                   Yes
# 4                     No              Fiber optic  ...                    No
# ...                  ...                      ...  ...                   ...
# 7262                  No                      DSL  ...                    No
# 7263                 Yes              Fiber optic  ...                    No
# 7264                  No                      DSL  ...                   Yes
# 7265                  No                      DSL  ...                    No
# 7266    No phone service                      DSL  ...                   Yes
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7262                        No                  Yes                   No
# 7263                        No                   No                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7262                       No         One year                       No
# 7263                      Yes   Month-to-month                      Yes
# 7264                       No   Month-to-month                      Yes
# 7265                      Yes         Two year                       No
# 7266                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly  account.Charges.Total
# 0             Mailed check                   65.60                  593.3
# 1             Mailed check                   59.90                  542.4
# 2         Electronic check                   73.90                 280.85
# 3         Electronic check                   98.00                1237.85
# 4             Mailed check                   83.90                  267.4
# ...                    ...                     ...                    ...
# 7262          Mailed check                   55.15                  742.9
# 7263      Electronic check                   85.10                 1873.7
# 7264          Mailed check                   50.30                  92.75
# 7265          Mailed check                   67.85                4627.65
# 7266      Electronic check                   59.00                 3707.6
#
# [7267 rows x 21 columns]

# %%
clientes_normalizados['customer.Partner'].value_counts()
# Out:
# customer.Partner
# No     3749
# Yes    3518
# Name: count, dtype: int64

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   object
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# #🔧 Transformación

# %%
clientes_normalizados['internet.OnlineSecurity']=clientes_normalizados['internet.OnlineSecurity'].replace('No internet service','No')

# %%
clientes_normalizados["Churn"]=clientes_normalizados["Churn"].map({"Yes": True, "No": False})

# %%
clientes_normalizados["Churn"]=clientes_normalizados["Churn"].astype(bool)

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   bool
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   object
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
clientes_normalizados['customer.SeniorCitizen']=clientes_normalizados['customer.SeniorCitizen'].astype(bool)

# %%
columnas=['customer.Partner','customer.Dependents','phone.PhoneService','account.PaperlessBilling']

# %%
clientes_normalizados[columnas] = clientes_normalizados[columnas].applymap(lambda x: True if x=="Yes" else False)
# Out:
# /tmp/ipython-input-1544746536.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   clientes_normalizados[columnas] = clientes_normalizados[columnas].applymap(lambda x: True if x=="Yes" else False)

# %%
clientes_normalizados[columnas]=clientes_normalizados[columnas].astype(bool)

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   bool
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   bool
#  4   customer.Partner           7267 non-null   bool
#  5   customer.Dependents        7267 non-null   bool
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   bool
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
#  13  internet.TechSupport       7267 non-null   object
#  14  internet.StreamingTV       7267 non-null   object
#  15  internet.StreamingMovies   7267 non-null   object
#  16  account.Contract           7267 non-null   object
#  17  account.PaperlessBilling   7267 non-null   bool
#  18  account.PaymentMethod      7267 non-null   object
#  19  account.Charges.Monthly    7267 non-null   float64
#  20  account.Charges.Total      7267 non-null   object
# dtypes: bool(6), float64(1), int64(1), object(13)
# memory usage: 894.3+ KB

# %%
clientes_normalizados["account.Charges.Total"]=clientes_normalizados["account.Charges.Total"].str.replace(r"[^0-9.]", "", regex=True)

# %%
num_nan = clientes_normalizados["account.Charges.Total"].isna().sum()
print("Cantidad de NaN:", num_nan)
# Out:
# Cantidad de NaN: 0

# %%
num_empty = (clientes_normalizados["account.Charges.Total"] == "").sum()
print("Cantidad de cadenas vacías:", num_empty)
# Out:
# Cantidad de cadenas vacías: 11

# %%
clientes_normalizados[clientes_normalizados['account.Charges.Total']=='']
# Out:
#       customerID  Churn customer.gender  customer.SeniorCitizen  \
# 975   1371-DWPAZ  False          Female                   False
# 1775  2520-SGTTA  False          Female                   False
# 1955  2775-SEFEE  False            Male                   False
# 2075  2923-ARZLG  False            Male                   False
# 2232  3115-CZMZD  False            Male                   False
# 2308  3213-VVOLG  False            Male                   False
# 2930  4075-WKNIU  False          Female                   False
# 3134  4367-NUYAO  False            Male                   False
# 3203  4472-LVYGI  False          Female                   False
# 4169  5709-LVOEQ  False          Female                   False
# 5599  7644-OMVMY  False            Male                   False
#
#       customer.Partner  customer.Dependents  customer.tenure  \
# 975               True                 True                0
# 1775              True                 True                0
# 1955             False                 True                0
# 2075              True                 True                0
# 2232             False                 True                0
# 2308              True                 True                0
# 2930              True                 True                0
# 3134              True                 True                0
# 3203              True                 True                0
# 4169              True                 True                0
# 5599              True                 True                0
#
#       phone.PhoneService phone.MultipleLines internet.InternetService  ...  \
# 975                False    No phone service                      DSL  ...
# 1775                True                  No                       No  ...
# 1955                True                 Yes                      DSL  ...
# 2075                True                  No                       No  ...
# 2232                True                  No                       No  ...
# 2308                True                 Yes                       No  ...
# 2930                True                 Yes                      DSL  ...
# 3134                True                 Yes                       No  ...
# 3203               False    No phone service                      DSL  ...
# 4169                True                  No                      DSL  ...
# 5599                True                  No                       No  ...
#
#      internet.OnlineBackup internet.DeviceProtection internet.TechSupport  \
# 975                    Yes                       Yes                  Yes
# 1775   No internet service       No internet service  No internet service
# 1955                   Yes                        No                  Yes
# 2075   No internet service       No internet service  No internet service
# 2232   No internet service       No internet service  No internet service
# 2308   No internet service       No internet service  No internet service
# 2930                   Yes                       Yes                  Yes
# 3134   No internet service       No internet service  No internet service
# 3203                    No                       Yes                  Yes
# 4169                   Yes                       Yes                   No
# 5599   No internet service       No internet service  No internet service
#
#      internet.StreamingTV internet.StreamingMovies account.Contract  \
# 975                   Yes                       No         Two year
# 1775  No internet service      No internet service         Two year
# 1955                   No                       No         Two year
# 2075  No internet service      No internet service         One year
# 2232  No internet service      No internet service         Two year
# 2308  No internet service      No internet service         Two year
# 2930                  Yes                       No         Two year
# 3134  No internet service      No internet service         Two year
# 3203                  Yes                       No         Two year
# 4169                  Yes                      Yes         Two year
# 5599  No internet service      No internet service         Two year
#
#      account.PaperlessBilling      account.PaymentMethod  \
# 975                     False    Credit card (automatic)
# 1775                    False               Mailed check
# 1955                     True  Bank transfer (automatic)
# 2075                     True               Mailed check
# 2232                    False               Mailed check
# 2308                    False               Mailed check
# 2930                    False               Mailed check
# 3134                    False               Mailed check
# 3203                     True  Bank transfer (automatic)
# 4169                    False               Mailed check
# 5599                    False               Mailed check
#
#      account.Charges.Monthly  account.Charges.Total
# 975                    56.05
# 1775                   20.00
# 1955                   61.90
# 2075                   19.70
# 2232                   20.25
# 2308                   25.35
# 2930                   73.35
# 3134                   25.75
# 3203                   52.55
# 4169                   80.85
# 5599                   19.85
#
# [11 rows x 21 columns]

# %%
clientes_normalizados = clientes_normalizados[
    ~(clientes_normalizados["account.Charges.Total"].isna() |
      (clientes_normalizados["account.Charges.Total"] == ""))
]

# %%
clientes_normalizados['account.Charges.Total']=clientes_normalizados['account.Charges.Total'].astype(np.float64)
# Out:
# /tmp/ipython-input-2970800526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clientes_normalizados['account.Charges.Total']=clientes_normalizados['account.Charges.Total'].astype(np.float64)

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7256 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7256 non-null   object
#  1   Churn                      7256 non-null   bool
#  2   customer.gender            7256 non-null   object
#  3   customer.SeniorCitizen     7256 non-null   bool
#  4   customer.Partner           7256 non-null   bool
#  5   customer.Dependents        7256 non-null   bool
#  6   customer.tenure            7256 non-null   int64
#  7   phone.PhoneService         7256 non-null   bool
#  8   phone.MultipleLines        7256 non-null   object
#  9   internet.InternetService   7256 non-null   object
#  10  internet.OnlineSecurity    7256 non-null   object
#  11  internet.OnlineBackup      7256 non-null   object
#  12  internet.DeviceProtection  7256 non-null   object
#  13  internet.TechSupport       7256 non-null   object
#  14  internet.StreamingTV       7256 non-null   object
#  15  internet.StreamingMovies   7256 non-null   object
#  16  account.Contract           7256 non-null   object
#  17  account.PaperlessBilling   7256 non-null   bool
#  18  account.PaymentMethod      7256 non-null   object
#  19  account.Charges.Monthly    7256 non-null   float64
#  20  account.Charges.Total      7256 non-null   float64
# dtypes: bool(6), float64(2), int64(1), object(12)
# memory usage: 949.5+ KB

# %%
clientes_normalizados['account.PaymentMethod'].value_counts()
# Out:
# account.PaymentMethod
# Electronic check             2445
# Mailed check                 1657
# Bank transfer (automatic)    1587
# Credit card (automatic)      1567
# Name: count, dtype: int64

# %%
clientes_normalizados["customerID"].duplicated().any()
# Out:
# np.False_

# %%
clientes_normalizados["GastoDiario"] = clientes_normalizados["account.Charges.Monthly"] / 30
# Out:
# /tmp/ipython-input-198773152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clientes_normalizados["GastoDiario"] = clientes_normalizados["account.Charges.Monthly"] / 30

# %%
clientes_normalizados=clientes_normalizados.rename(columns={'GastoDiario': 'gasto_diario'})

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7256 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7256 non-null   object
#  1   Churn                      7256 non-null   bool
#  2   customer.gender            7256 non-null   object
#  3   customer.SeniorCitizen     7256 non-null   bool
#  4   customer.Partner           7256 non-null   bool
#  5   customer.Dependents        7256 non-null   bool
#  6   customer.tenure            7256 non-null   int64
#  7   phone.PhoneService         7256 non-null   bool
#  8   phone.MultipleLines        7256 non-null   object
#  9   internet.InternetService   7256 non-null   object
#  10  internet.OnlineSecurity    7256 non-null   object
#  11  internet.OnlineBackup      7256 non-null   object
#  12  internet.DeviceProtection  7256 non-null   object
#  13  internet.TechSupport       7256 non-null   object
#  14  internet.StreamingTV       7256 non-null   object
#  15  internet.StreamingMovies   7256 non-null   object
#  16  account.Contract           7256 non-null   object
#  17  account.PaperlessBilling   7256 non-null   bool
#  18  account.PaymentMethod      7256 non-null   object
#  19  account.Charges.Monthly    7256 non-null   float64
#  20  account.Charges.Total      7256 non-null   float64
#  21  gasto_diario               7256 non-null   float64
# dtypes: bool(6), float64(3), int64(1), object(12)
# memory usage: 1006.2+ KB

# %% [markdown]
# #📊 Carga y análisis

# %%
clientes_normalizados.describe()
# Out:
#        customer.tenure  account.Charges.Monthly  account.Charges.Total  \
# count      7256.000000              7256.000000            7256.000000
# mean         32.395535                64.755423            2280.634213
# std          24.558067                30.125739            2268.632997
# min           1.000000                18.250000              18.800000
# 25%           9.000000                35.450000             400.225000
# 50%          29.000000                70.300000            1391.000000
# 75%          55.000000                89.900000            3785.300000
# max          72.000000               118.750000            8684.800000
#
#        gasto_diario
# count   7256.000000
# mean       2.158514
# std        1.004191
# min        0.608333
# 25%        1.181667
# 50%        2.343333
# 75%        2.996667
# max        3.958333

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de Churn
churn_counts = clientes_normalizados['Churn'].value_counts()
churn_labels = churn_counts.index
churn_sizes = churn_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    churn_sizes,
    labels=churn_labels,
    autopct=lambda p: f"{int(p*sum(churn_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes que dejaron la empresa (Churn)", fontsize=16)

plt.show()

# %%
ex_clientes = clientes_normalizados[clientes_normalizados['Churn'] == True]

clientes_mantenidos = clientes_normalizados[clientes_normalizados['Churn'] == False]

# %% [markdown]
# ## **Analisis por tipo de cliente**

# %% [markdown]
# ### **Analisis por genero**

# %%
ex_clientes
# Out:
#       customerID  Churn customer.gender  customer.SeniorCitizen  \
# 2     0004-TLHLJ   True            Male                   False
# 3     0011-IGKFF   True            Male                    True
# 4     0013-EXCHZ   True          Female                    True
# 18    0022-TCJCI   True            Male                    True
# 19    0023-HGHWL   True            Male                    True
# ...          ...    ...             ...                     ...
# 7246  9965-YOKZB   True            Male                    True
# 7247  9966-VYRTZ   True          Female                   False
# 7260  9985-MWVIX   True          Female                   False
# 7261  9986-BONCE   True          Female                   False
# 7263  9992-RRAMN   True            Male                   False
#
#       customer.Partner  customer.Dependents  customer.tenure  \
# 2                False                False                4
# 3                 True                False               13
# 4                 True                False                3
# 18               False                False               45
# 19               False                False                1
# ...                ...                  ...              ...
# 7246             False                False                9
# 7247              True                 True               31
# 7260             False                False                1
# 7261             False                False                4
# 7263              True                False               22
#
#       phone.PhoneService phone.MultipleLines internet.InternetService  ...  \
# 2                   True                  No              Fiber optic  ...
# 3                   True                  No              Fiber optic  ...
# 4                   True                  No              Fiber optic  ...
# 18                  True                  No                      DSL  ...
# 19                 False    No phone service                      DSL  ...
# ...                  ...                 ...                      ...  ...
# 7246                True                 Yes              Fiber optic  ...
# 7247                True                  No                       No  ...
# 7260                True                  No              Fiber optic  ...
# 7261                True                  No                       No  ...
# 7263                True                 Yes              Fiber optic  ...
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# 18                         Yes                   No                   No
# 19                          No                   No                   No
# ...                        ...                  ...                  ...
# 7246                        No                   No                   No
# 7247       No internet service  No internet service  No internet service
# 7260                        No                   No                   No
# 7261       No internet service  No internet service  No internet service
# 7263                        No                   No                   No
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 2                          No   Month-to-month                     True
# 3                         Yes   Month-to-month                     True
# 4                          No   Month-to-month                     True
# 18                        Yes         One year                    False
# 19                         No   Month-to-month                     True
# ...                       ...              ...                      ...
# 7246                      Yes   Month-to-month                     True
# 7247      No internet service   Month-to-month                     True
# 7260                       No   Month-to-month                     True
# 7261      No internet service   Month-to-month                    False
# 7263                      Yes   Month-to-month                     True
#
#           account.PaymentMethod  account.Charges.Monthly  \
# 2              Electronic check                    73.90
# 3              Electronic check                    98.00
# 4                  Mailed check                    83.90
# 18      Credit card (automatic)                    62.70
# 19             Electronic check                    25.10
# ...                         ...                      ...
# 7246           Electronic check                    83.85
# 7247               Mailed check                    19.55
# 7260               Mailed check                    70.15
# 7261  Bank transfer (automatic)                    20.95
# 7263           Electronic check                    85.10
#
#      account.Charges.Total  gasto_diario
# 2                   280.85      2.463333
# 3                  1237.85      3.266667
# 4                   267.40      2.796667
# 18                 2791.50      2.090000
# 19                   25.10      0.836667
# ...                    ...           ...
# 7246                790.15      2.795000
# 7247                658.95      0.651667
# 7260                 70.15      2.338333
# 7261                 85.50      0.698333
# 7263               1873.70      2.836667
#
# [2093 rows x 22 columns]

# %%
clientes_mantenidos
# Out:
#       customerID  Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO  False          Female                   False
# 1     0003-MKNFE  False            Male                   False
# 5     0013-MHZWF  False          Female                   False
# 6     0013-SMEOE  False          Female                    True
# 7     0014-BMAQU  False            Male                   False
# ...          ...    ...             ...                     ...
# 7259  9979-RGMZT  False          Female                   False
# 7262  9987-LUTYD  False          Female                   False
# 7264  9992-UJOEL  False            Male                   False
# 7265  9993-LHIEB  False            Male                   False
# 7266  9995-HOTOH  False            Male                   False
#
#       customer.Partner  customer.Dependents  customer.tenure  \
# 0                 True                 True                9
# 1                False                False                9
# 5                False                 True                9
# 6                 True                False               71
# 7                 True                False               63
# ...                ...                  ...              ...
# 7259             False                False                7
# 7262             False                False               13
# 7264             False                False                2
# 7265              True                 True               67
# 7266              True                 True               63
#
#       phone.PhoneService phone.MultipleLines internet.InternetService  ...  \
# 0                   True                  No                      DSL  ...
# 1                   True                 Yes                      DSL  ...
# 5                   True                  No                      DSL  ...
# 6                   True                  No              Fiber optic  ...
# 7                   True                 Yes              Fiber optic  ...
# ...                  ...                 ...                      ...  ...
# 7259                True                  No              Fiber optic  ...
# 7262                True                  No                      DSL  ...
# 7264                True                  No                      DSL  ...
# 7265                True                  No                      DSL  ...
# 7266               False    No phone service                      DSL  ...
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 5                           No                  Yes                  Yes
# 6                          Yes                  Yes                  Yes
# 7                           No                  Yes                   No
# ...                        ...                  ...                  ...
# 7259                        No                   No                  Yes
# 7262                        No                  Yes                   No
# 7264                        No                   No                   No
# 7265                       Yes                  Yes                   No
# 7266                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                     True
# 1                         Yes   Month-to-month                    False
# 5                         Yes   Month-to-month                     True
# 6                         Yes         Two year                     True
# 7                          No         Two year                     True
# ...                       ...              ...                      ...
# 7259                      Yes         One year                     True
# 7262                       No         One year                    False
# 7264                       No   Month-to-month                     True
# 7265                      Yes         Two year                    False
# 7266                      Yes         Two year                    False
#
#           account.PaymentMethod  account.Charges.Monthly  \
# 0                  Mailed check                    65.60
# 1                  Mailed check                    59.90
# 5       Credit card (automatic)                    69.40
# 6     Bank transfer (automatic)                   109.70
# 7       Credit card (automatic)                    84.65
# ...                         ...                      ...
# 7259               Mailed check                    94.05
# 7262               Mailed check                    55.15
# 7264               Mailed check                    50.30
# 7265               Mailed check                    67.85
# 7266           Electronic check                    59.00
#
#      account.Charges.Total  gasto_diario
# 0                   593.30      2.186667
# 1                   542.40      1.996667
# 5                   571.45      2.313333
# 6                  7904.25      3.656667
# 7                  5377.80      2.821667
# ...                    ...           ...
# 7259                633.45      3.135000
# 7262                742.90      1.838333
# 7264                 92.75      1.676667
# 7265               4627.65      2.261667
# 7266               3707.60      1.966667
#
# [5163 rows x 22 columns]

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
gender_counts = clientes_mantenidos['customer.gender'].value_counts()
gender_labels = gender_counts.index
gender_sizes = gender_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    gender_sizes,
    labels=gender_labels,
    autopct=lambda p: f"{int(p*sum(gender_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes por genero", fontsize=16)

plt.show()

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes ex-clientes
gender_counts = ex_clientes['customer.gender'].value_counts()
gender_labels = gender_counts.index
gender_sizes = gender_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    gender_sizes,
    labels=gender_labels,
    autopct=lambda p: f"{int(p*sum(gender_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de ex-clientes por genero", fontsize=16)

plt.show()

# %% [markdown]
# La distribucion de clientes parece ser equitativa, no se ve ninguna diferencia entre el genero de los clientes con respecto a su desviacion, por lo tanto se concluye que no existe relacion

# %% [markdown]
# ### **Analisis de mayores de 65**

# %%
clientes_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7256 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7256 non-null   object
#  1   Churn                      7256 non-null   bool
#  2   customer.gender            7256 non-null   object
#  3   customer.SeniorCitizen     7256 non-null   bool
#  4   customer.Partner           7256 non-null   bool
#  5   customer.Dependents        7256 non-null   bool
#  6   customer.tenure            7256 non-null   int64
#  7   phone.PhoneService         7256 non-null   bool
#  8   phone.MultipleLines        7256 non-null   object
#  9   internet.InternetService   7256 non-null   object
#  10  internet.OnlineSecurity    7256 non-null   object
#  11  internet.OnlineBackup      7256 non-null   object
#  12  internet.DeviceProtection  7256 non-null   object
#  13  internet.TechSupport       7256 non-null   object
#  14  internet.StreamingTV       7256 non-null   object
#  15  internet.StreamingMovies   7256 non-null   object
#  16  account.Contract           7256 non-null   object
#  17  account.PaperlessBilling   7256 non-null   bool
#  18  account.PaymentMethod      7256 non-null   object
#  19  account.Charges.Monthly    7256 non-null   float64
#  20  account.Charges.Total      7256 non-null   float64
#  21  gasto_diario               7256 non-null   float64
# dtypes: bool(6), float64(3), int64(1), object(12)
# memory usage: 1006.2+ KB

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
senior_counts = clientes_mantenidos['customer.SeniorCitizen'].value_counts()
senior_labels = senior_counts.index
senior_sizes = senior_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    senior_sizes,
    labels=senior_labels,
    autopct=lambda p: f"{int(p*sum(senior_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes mantenidos mayores o iguales a 65 años", fontsize=16)

plt.show()

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
senior_counts = ex_clientes['customer.SeniorCitizen'].value_counts()
senior_labels = senior_counts.index
senior_sizes = senior_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    senior_sizes,
    labels=senior_labels,
    autopct=lambda p: f"{int(p*sum(senior_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes que cancelaron mayores o iguales a 65 años", fontsize=16)

plt.show()

# %%
sns.set_theme(style="whitegrid")

# Renombrar categorías para el gráfico
clientes_normalizados["EdadCategoria"] = clientes_normalizados["customer.SeniorCitizen"].map({True: ">=65", False: "<65"})

# Contar clientes por categoría de edad y Churn
conteo = clientes_normalizados.groupby(["EdadCategoria", "Churn"]).size().reset_index(name="Cantidad")

# Crear gráfica de barras horizontales
plt.figure(figsize=(8,6))
ax = sns.barplot(
    data=conteo,
    y="EdadCategoria",        # eje Y = categoría de edad
    x="Cantidad",             # eje X = cantidad
    hue="Churn",
    palette={True: "red", False: "green"}
)

plt.title("Clientes por categoría de edad", fontsize=16)
plt.xlabel("Número de Clientes")
plt.ylabel("Categoría de Edad")

# Personalizar leyenda
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=["No Cancelaron", "Cancelaron"])

# Agregar números encima de cada barra
for p in ax.patches:
    width = p.get_width()
    ax.text(width + 0.5,          # posición X (al lado de la barra)
            p.get_y() + p.get_height()/2,  # posición Y (centro de la barra)
            int(width),          # texto = valor entero
            va='center')

plt.show()

# %% [markdown]
# Se puede observar que aunque la cantidad bruta de personas que mantiene o cancelaron la suscripcion es similar en los clientes mayores a 65 años, el porcentaje de los clientes mayores a 65 años que cancelaron es mayor a los que no cancelaron con respecto a los clientes menores a 65 años, lo que indica que los clientes mayores a 65 años tienden mas a cancelar que los menores a 65

# %% [markdown]
# ### **Analisis de clientes con pareja**

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
partner_counts = clientes_mantenidos['customer.Partner'].value_counts()
partner_labels = partner_counts.index
partner_sizes = partner_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    partner_sizes,
    labels=partner_labels,
    autopct=lambda p: f"{int(p*sum(partner_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes con pareja", fontsize=16)

plt.show()

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
partner_counts = ex_clientes['customer.Partner'].value_counts()
partner_labels = partner_counts.index
partner_sizes = partner_counts.values

# Paleta pastel base de seaborn
paleta = sns.color_palette("pastel")

# Asignar color fijo: True = paleta[0], False = paleta[1]
colores = [paleta[0] if label==True else paleta[1] for label in partner_labels]

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    partner_sizes,
    labels=partner_labels,
    autopct=lambda p: f"{int(p*sum(partner_sizes)/100)} ({p:.1f}%)",
    startangle=90,
    colors=colores
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de ex-clientes con pareja ", fontsize=16)

plt.show()

# %% [markdown]
# Se puede observar que los clientes con pareja tienden mas a mantenererse, mientras que los solteros tienden mas a cancelar la susbcripcion, puesto que mientras que el porcentaje de clientes sin pareja representan un 47% de los clientes actuales, lo cual es un porcentaje bueno, casi la mitad, al ver el porcentaje de los clientes que cancelan, los clientes solteros aumentan a un 62% de los clientes totales que cancelaron

# %% [markdown]
# ### **Analisis de clientes con dependientes**

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
dependents_counts = clientes_mantenidos['customer.Dependents'].value_counts()
dependents_labels = dependents_counts.index
dependents_sizes = dependents_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    dependents_sizes,
    labels=dependents_labels,
    autopct=lambda p: f"{int(p*sum(dependents_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de clientes con dependientes", fontsize=16)

plt.show()

# %%
# Estilo de seaborn
sns.set_theme(style="whitegrid")

# Contar valores de clientes mantenidos
dependents_counts = ex_clientes['customer.Dependents'].value_counts()
dependents_labels = dependents_counts.index
dependents_sizes = dependents_counts.values

# Crear la gráfica de pastel
fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    dependents_sizes,
    labels=dependents_labels,
    autopct=lambda p: f"{int(p*sum(dependents_sizes)/100)} ({p:.1f}%)",  # número y porcentaje
    startangle=90,
    colors=sns.color_palette("pastel")
)

# Estilo de textos
for text in texts + autotexts:
    text.set_fontsize(12)

# Título
ax.set_title("Distribución de ex-clientes con dependientes", fontsize=16)

plt.show()

# %% [markdown]
# Se puede observar como los clientes sin dependientes tienen una tendencia mucho mayor a cancelar frente a los no dependientes, puesto que mientras que en los clientes activos, los clientes sin dependientes representan 65% de los clientes, en los que cancelaron este porcentaje aumenta hasta un 81%.
# Esto junto con el analisis de los clientes con pareja da a entender que los clientes mas solitarios son mas propensos a cancelar sus servicios

# %% [markdown]
# ## **Analisis por tiempo de contrato**

# %%
clientes_normalizados['customer.tenure'].value_counts()
# Out:
# customer.tenure
# 1     634
# 72    369
# 2     246
# 3     207
# 4     185
#      ...
# 38     60
# 28     60
# 39     59
# 44     54
# 36     50
# Name: count, Length: 72, dtype: int64

# %%
sns.set_theme(style="whitegrid")

# Crear bins de 6 en 6 hasta 72 meses
bins = list(range(0, 73, 6))  # 0,6,12,...72
labels = [f"{b}-{b+5}" for b in bins[:-1]]  # etiquetas: "0-5", "6-11", etc.

# Crear columna de rango de tenure
clientes_normalizados["TenureGrupo"] = pd.cut(clientes_normalizados["customer.tenure"], bins=bins, labels=labels, right=True, include_lowest=True)

# Contar clientes por grupo de tenure y Churn
conteo = clientes_normalizados.groupby(["TenureGrupo", "Churn"]).size().reset_index(name="Cantidad")

# Definir colores pastel fijos
colores = {True: sns.color_palette("pastel")[1], False: sns.color_palette("pastel")[0]}

# Crear gráfica de barras verticales
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=conteo,
    x="TenureGrupo",
    y="Cantidad",
    hue="Churn",
    palette=colores
)

plt.title("Cantidad de clientes según meses de contrato y Churn", fontsize=16)
plt.xlabel("Meses de Contrato (Tenure)")
plt.ylabel("Número de Clientes")

# Personalizar leyenda
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles, labels=["No Cancelaron", "Cancelaron"], title="Churn")

# Agregar valores encima de cada barra
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2, height + 0.5, int(height), ha='center')

plt.show()
# Out:
# /tmp/ipython-input-476559826.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   conteo = clientes_normalizados.groupby(["TenureGrupo", "Churn"]).size().reset_index(name="Cantidad")

# %% [markdown]
# #📄Informe final
